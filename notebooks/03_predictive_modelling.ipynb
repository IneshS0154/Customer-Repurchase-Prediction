# %% [markdown]
# # 03 — Predictive Statistical Modelling (Task 5)
#
# Brief section 6. Repurchase (binary): logistic regression baseline, then
# stepwise vs LASSO vs elastic net logistic regression. Future spend (continuous):
# linear regression on log spend vs Gamma GLM with log link.
#
# Evaluate beyond accuracy: AUC, calibration/Brier score, top-decile lift,
# expected-profit comparison, RMSE/MAE. Check VIF, linearity of the logit,
# residuals, and influential observations.

# %%
import sys
sys.path.append('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

clean = pd.read_csv('../data/processed/invoice_lines_clean.csv', parse_dates=['InvoiceDate'])
customers = pd.read_csv('../data/processed/customer_table.csv')

sns.set_theme(style='whitegrid')
pd.set_option('display.max_columns', None)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, brier_score_loss, mean_squared_error, mean_absolute_error
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# ## Train/test split

# %%
FEATURES = ['Recency', 'Frequency', 'Monetary', 'TenureDays', 'DistinctProducts',
            'AvgBasketValue', 'IsUK', 'AcquiredInQ4', 'CancellationRate']

X = customers[FEATURES]
y_class = customers['Repurchase']
y_reg = customers.loc[customers['Repurchase'] == 1, 'FutureSpend']  # spend model: repurchasers only, or model all with zeros — decide & justify

X_train, X_test, y_train, y_test = train_test_split(X, y_class, test_size=0.25, random_state=42, stratify=y_class)

# %% [markdown]
# ## Model 1 — Logistic regression baseline (odds ratios)

# %%
# TODO: statsmodels Logit for interpretable coefficients / odds ratios
# TODO: sklearn LogisticRegression for held-out AUC

# %% [markdown]
# ## Model 2 — Stepwise vs LASSO vs Elastic Net logistic regression

# %%
# TODO: LogisticRegressionCV(penalty='elasticnet', solver='saga', l1_ratios=[.1,.5,.9])
# TODO: compare coefficient stability vs baseline; discuss correlated RFM features

# %% [markdown]
# ## Assumption checks

# %%
# TODO: VIF via statsmodels.stats.outliers_influence.variance_inflation_factor
# TODO: Box-Tidwell test for linearity of the logit
# TODO: influence/leverage diagnostics

# %% [markdown]
# ## Evaluation beyond accuracy

# %%
# TODO: AUC, calibration curve (sklearn.calibration.calibration_curve), Brier score
# TODO: top-decile lift
# TODO: expected-profit comparison across thresholds/models

# %% [markdown]
# ## Future spend — Linear regression (log) vs Gamma GLM

# %%
# TODO: smf.ols('np.log1p(FutureSpend) ~ ...', data=...)
# TODO: smf.glm('FutureSpend ~ ...', data=..., family=sm.families.Gamma(link=sm.families.links.Log()))
# TODO: RMSE / MAE on held-out spend

# %% [markdown]
# ## Recommendation
#
# _Expected: penalised (LASSO/elastic net) logistic regression — interpretability, stability, calibration over raw AUC._
